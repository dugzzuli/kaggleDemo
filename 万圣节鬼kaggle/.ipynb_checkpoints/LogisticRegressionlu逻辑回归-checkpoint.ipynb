# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

# %%
trainpath="train.csv"
testpath="test.path"
samplepath="sample_submission.csv"
#读取训练集数据
trainset=pd.read_csv(trainpath)
#分离训练数据
x_train=trainset.drop(["type","color"],axis=1).values

# %%
color_train=trainset["color"]

# %%
le=LabelEncoder().fit(color_train)

# %%
le=LabelEncoder().fit(color_train)

# %%
color_t_2=le.transform(color_train)

# %%
color_t_2
# Out:
# array([3, 4, 0, 0, 4, 4, 5, 3, 2, 5, 3, 3, 5, 0, 3, 3, 0, 0, 2, 4, 3, 5, 3,
#        5, 3, 5, 3, 4, 5, 3, 3, 4, 5, 4, 0, 2, 5, 3, 5, 0, 5, 0, 5, 0, 5, 4,
#        1, 3, 3, 3, 0, 4, 3, 4, 5, 2, 3, 3, 0, 5, 3, 4, 5, 0, 5, 0, 5, 3, 0,
#        0, 5, 5, 5, 4, 5, 3, 3, 5, 3, 3, 5, 5, 4, 0, 2, 3, 5, 0, 3, 5, 3, 3,
#        3, 5, 0, 3, 0, 4, 5, 2, 0, 3, 4, 5, 5, 3, 5, 2, 5, 3, 5, 0, 3, 4, 5,
#        5, 5, 1, 3, 3, 5, 5, 5, 4, 3, 5, 4, 4, 3, 0, 4, 5, 3, 3, 2, 3, 3, 3,
#        5, 3, 5, 5, 4, 5, 3, 3, 5, 3, 5, 3, 3, 1, 3, 3, 5, 5, 3, 5, 1, 3, 4,
#        5, 3, 3, 3, 5, 4, 0, 3, 5, 3, 1, 5, 4, 0, 3, 5, 5, 0, 0, 5, 5, 4, 5,
#        3, 5, 0, 3, 5, 3, 3, 0, 5, 4, 0, 5, 3, 5, 5, 5, 5, 4, 5, 5, 5, 4, 3,
#        0, 5, 5, 4, 5, 4, 5, 5, 5, 5, 5, 0, 5, 3, 3, 5, 4, 3, 0, 5, 2, 3, 4,
#        5, 3, 5, 3, 5, 5, 0, 5, 4, 3, 3, 3, 3, 3, 0, 5, 5, 2, 3, 5, 5, 5, 5,
#        3, 5, 3, 3, 5, 2, 3, 5, 5, 2, 5, 5, 5, 2, 3, 3, 5, 3, 1, 3, 5, 5, 3,
#        4, 4, 3, 5, 3, 5, 5, 3, 4, 5, 3, 1, 0, 3, 1, 5, 2, 3, 1, 2, 5, 3, 5,
#        3, 5, 5, 5, 2, 0, 5, 4, 5, 5, 3, 5, 4, 3, 5, 3, 3, 3, 5, 5, 5, 3, 3,
#        5, 3, 1, 3, 5, 5, 1, 0, 0, 5, 5, 3, 3, 3, 5, 5, 3, 0, 5, 5, 5, 2, 3,
#        3, 5, 0, 1, 3, 3, 5, 4, 5, 0, 3, 4, 4, 3, 2, 3, 3, 3, 5, 3, 5, 2, 4,
#        3, 3, 5], dtype=int64)

# %%
trainset["color"]=color_t_2

# %%
trainset
# Out:
#       id  bone_length  rotting_flesh  hair_length  has_soul  color    type
# 0      0     0.354512       0.350839     0.465761  0.781142      3   Ghoul
# 354  847     0.356999       0.671331     0.296784  0.689980      0   Ghost
# 355  849     0.440133       0.391157     0.571983  0.431373      3  Goblin
# 356  851     0.445547       0.241139     0.558614  0.399302      4  Goblin
# 357  855     0.434891       0.667160     0.798618  0.460061      4   Ghoul
# 358  858     0.440432       0.309498     0.203057  0.194105      3   Ghost
# 359  861     0.626017       0.172182     0.408422  0.644941      2   Ghoul
# 360  864     0.467785       0.420135     0.631894  0.386509      3   Ghoul
# 361  867     0.501022       0.584847     0.656230  0.469886      3   Ghoul
# 362  873     0.377449       0.466158     0.497351  0.393305      3  Goblin
# 363  874     0.507583       0.799623     0.334520  0.344403      5   Ghost
# 364  877     0.486744       0.462666     0.840013  0.353383      3  Goblin
# 365  878     0.406062       0.449944     0.788983  0.428553      5   Ghoul
# 366  886     0.458132       0.391760     0.660590  0.635689      2  Goblin
# 367  889     0.331936       0.564836     0.539216  0.551471      4   Ghost
# 368  890     0.481640       0.501147     0.496446  0.544003      3   Ghoul
# 369  896     0.294943       0.771286     0.583503  0.300618      3   Ghost
# 370  897     0.670200       0.768469     0.737274  0.608384      5   Ghoul
#
# [371 rows x 7 columns]

# %%
y_type=trainset["type"]

# %%
le=LabelEncoder().fit(y_type)

# %%
y_t_2=le.transform(y_type)

# %%
trainset["type"]=y_t_2

# %%
#保存去除掉id的数据集
trainset_2=trainset.drop(["id"],axis=1)

# %%
x_train_3=trainset_2.drop(["type"],axis=1).values

# %%
y_train_3=trainset_2["type"]

# %%
y_train_3
# Out:
# 0      1
# 1      2
# 2      1
# 3      1
# 4      0
# 5      2
# 6      2
# 7      1
# 8      0
# 9      0
# 10     2
# 11     1
# 12     1
# 13     2
# 14     2
# 15     1
# 16     0
# 17     1
# 18     1
# 19     0
# 20     2
# 21     1
# 22     2
# 23     1
# 24     1
# 25     0
# 26     2
# 27     2
# 28     2
# 29     2
#       ..
# 341    2
# 342    1
# 343    2
# 344    0
# 345    1
# 346    2
# 347    0
# 348    2
# 349    1
# 350    0
# 351    2
# 352    1
# 353    2
# 354    0
# 355    2
# 356    2
# 357    1
# 358    0
# 359    1
# 360    1
# 361    1
# 362    2
# 363    0
# 364    2
# 365    1
# 366    2
# 367    0
# 368    1
# 369    0
# 370    1
# Name: type, dtype: int64

# %%
log_reg = LogisticRegression(C=2000, multi_class="multinomial", tol=0.0001, solver='newton-cg')
log_reg.fit(x_train_3, y_train_3)
# Out:
# LogisticRegression(C=2000, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='multinomial',
#           n_jobs=1, penalty='l2', random_state=None, solver='newton-cg',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
test_set=pd.read_csv("test.csv")

# %%
id_list=test_set.pop("id")

# %%
color_test=test_set["color"]

# %%
le=LabelEncoder().fit(color_test)

# %%
color_test_ul=le.transform(color_test)

# %%
test_set["color"]=color_test_ul

# %%
y_pre=log_reg.predict(test_set)

# %%
submission = pd.DataFrame({'id':id_list,'type':y_pre})
submission.to_csv('submission2.csv')
